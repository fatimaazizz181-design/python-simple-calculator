# %%
print("1 - Add")
print("2 - Subtract")
print("3 - Multiply")
print("4 - Divide")
options = int(input("choose an operation: "))

if (options in [1,2,3,4]):
    num1 = int(input("enter first number: "))
    num2 = int(input("enter second number: "))

if (options == 1):
    result = num1 + num2
elif (options == 2):
    result = num1 - num2
elif (options == 3):
    result = num1 * num2
elif (options == 4):
    reult = num1 // num2

else:
    print("invalid operations")

print("The result of operation is {}" . format(result))
# Out:
# 1 - Add
# 2 - Subtract
# 3 - Multiply
# 4 - Divide
# choose an operation:  3
# enter first number:  45
# enter second number:  2
# The result of operation is 90
